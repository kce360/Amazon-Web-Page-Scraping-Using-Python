# %%
# import libraries 

from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
URL = 'https://www.amazon.com/Analyst-Graduate-Career-Professional-Spreadsheet/dp/B0C1MJSDHZ/ref=sr_1_2?crid=1LDY5UPNTVZ76&dib=eyJ2IjoiMSJ9.KEhZNoiS_9aZRnvUMTy2CzssveRYPrkOUp7-jrqaehqXMlSm0e65vh9Ai_0dg2FQP_GCdyP-I4JTNYX2uwipYYCRKxvQmtUPj6cpDYlWv1IwqcqfqNZ9k7dIIZvaLrvZgk5iuLjAiYhb9XO8AfY2HZT_w_iRAYaDcPcz0qLGius6qxh2V5E_nHj-d83KOB9ow8tkoPUs16s_LSJiVcBOpoYSAMV9yzNJHjUdEdmeglXTikFm1qUlJbAN4tYwGiZtgEnv5kT4l9LVZjPcH6WqGezOu4mpZsjZOKdFl1eltkA.pqk9EjvqGhihZP3spyTRdxYhuH51RxUulQMlTVCdJMA&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1714997447&refresh=1&sprefix=data%2Banalyst%2Btshirt%2Caps%2C731&sr=8-2&th=1&psc=1'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

page = requests.get(URL, headers = headers)
soup1 = BeautifulSoup(page.content, 'html.parser')
print(soup1)

#soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')

# %%
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us">
# <!-- sp:feature:head-start -->
# <head>
# <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
# <meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
title = soup2.find(id='productTitle').get_text()
print(title)
# Out:
#                     Data Analyst T Shirt Funny Gift for Data Analyst Graduate Career Professional Data Analyst Spreadsheet Unisex Tee

# %%
price = soup2.find(class_='aok-offscreen').get_text()
print(price)
# Out:
#                     $23.97

# %%
import datetime
today = datetime.date.today()
today

# %%
price = price.strip()[1:]
title = title.strip()

print(title)
print(price)
# Out:
# Data Analyst T Shirt Funny Gift for Data Analyst Graduate Career Professional Data Analyst Spreadsheet Unisex Tee
# 23.97

# %%
#creating a csv file
import csv

header = ['Title', 'Price', 'Date']
data = [title, price, today]

#commented out for the purpose of re-runnung
#with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    #writer = csv.writer(f)
    #writer.writerow(header)
    #writer.writerow(data)

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\kce36\AmazonWebScraperDataset.csv")
df
# Out:
#                                                Title  Price        Date
# 0  Data Analyst T Shirt Funny Gift for Data Analy...  23.97  2024-05-07
# 1  Data Analyst T Shirt Funny Gift for Data Analy...  23.97  2024-05-07

# %%
#adding data to the created csv

# %%
with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.amazon.com/Analyst-Graduate-Career-Professional-Spreadsheet/dp/B0C1MJSDHZ/ref=sr_1_2?crid=1LDY5UPNTVZ76&dib=eyJ2IjoiMSJ9.KEhZNoiS_9aZRnvUMTy2CzssveRYPrkOUp7-jrqaehqXMlSm0e65vh9Ai_0dg2FQP_GCdyP-I4JTNYX2uwipYYCRKxvQmtUPj6cpDYlWv1IwqcqfqNZ9k7dIIZvaLrvZgk5iuLjAiYhb9XO8AfY2HZT_w_iRAYaDcPcz0qLGius6qxh2V5E_nHj-d83KOB9ow8tkoPUs16s_LSJiVcBOpoYSAMV9yzNJHjUdEdmeglXTikFm1qUlJbAN4tYwGiZtgEnv5kT4l9LVZjPcH6WqGezOu4mpZsjZOKdFl1eltkA.pqk9EjvqGhihZP3spyTRdxYhuH51RxUulQMlTVCdJMA&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1714997447&refresh=1&sprefix=data%2Banalyst%2Btshirt%2Caps%2C731&sr=8-2&th=1&psc=1'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    page = requests.get(URL, headers = headers)
    soup1 = BeautifulSoup(page.content, 'html.parser')

    title = soup2.find(id='productTitle').get_text()
    price = soup2.find(class_='aok-offscreen').get_text()
    price = price.strip()[1:]
    title = title.strip()
    import datetime
    today = datetime.date.today()
    import csv
    header = ['Title', 'Price', 'Date']
    data = [title, price, today]
    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
    if(price < 14):
        send_mail()

# %%
while(True):
    check_price()
    time.sleep(86400)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 while(True):
# ----> 2     check_price()
#       3     time.sleep(5)
#
# Cell In[28], line 9, in check_price()
#       5 page = requests.get(URL, headers=headers)
#       7 soup1 = BeautifulSoup(page.content, "html.parser")
# ----> 9 soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
#      11 page = requests.get(URL, headers = headers)
#      12 soup1 = BeautifulSoup(page.content, 'html.parser')
#
# File ~\anaconda3\Lib\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# ...

# %%
#not checked by myself

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('xxx@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The Shirt you want is below $15! Now is your chance to buy!"
    body = " This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Analyst-Graduate-Career-Professional-Spreadsheet/dp/B0C1MJSDHZ/ref=sr_1_2?crid=1LDY5UPNTVZ76&dib=eyJ2IjoiMSJ9.KEhZNoiS_9aZRnvUMTy2CzssveRYPrkOUp7-jrqaehqXMlSm0e65vh9Ai_0dg2FQP_GCdyP-I4JTNYX2uwipYYCRKxvQmtUPj6cpDYlWv1IwqcqfqNZ9k7dIIZvaLrvZgk5iuLjAiYhb9XO8AfY2HZT_w_iRAYaDcPcz0qLGius6qxh2V5E_nHj-d83KOB9ow8tkoPUs16s_LSJiVcBOpoYSAMV9yzNJHjUdEdmeglXTikFm1qUlJbAN4tYwGiZtgEnv5kT4l9LVZjPcH6WqGezOu4mpZsjZOKdFl1eltkA.pqk9EjvqGhihZP3spyTRdxYhuH51RxUulQMlTVCdJMA&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1714997447&refresh=1&sprefix=data%2Banalyst%2Btshirt%2Caps%2C731&sr=8-2&th=1&psc=1"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'xxxx@gmail.com',
        msg
     
    )

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\kce36\AmazonWebScraperDataset.csv")
print(df)
# Out:
#                                                Title  Price        Date
# 0  Data Analyst T Shirt Funny Gift for Data Analy...  23.97  2024-05-07
# 1  Data Analyst T Shirt Funny Gift for Data Analy...  23.97  2024-05-07
# 2  Data Analyst T Shirt Funny Gift for Data Analy...  23.97  2024-05-07
# 3  Data Analyst T Shirt Funny Gift for Data Analy...  23.97  2024-05-07
# 4  Data Analyst T Shirt Funny Gift for Data Analy...  23.97  2024-05-07
# 5  Data Analyst T Shirt Funny Gift for Data Analy...  23.97  2024-05-07
# 6  Data Analyst T Shirt Funny Gift for Data Analy...  23.97  2024-05-07
